# %% [markdown]
# <a href="https://colab.research.google.com/github/siwarat40/40-satang-coding68/blob/main/final40_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# เลือกโจทย์ :การคำนวนค่าไฟฟ้า
# I : รับจำนวนหน่วยไฟที่ใช้
# P : คำนวนค่าไฟตามจำนวน
# O : ค่าไฟที่ต้องจ่าย
# ตัวแปร : หน่วยไฟ ค่าไฟ

print ("welcom to Coding Final 4/4 ")
print ("\n ( : satang:)" )



print ("ยินดีต้อนรับเข้าสู่โปรแกรมการคำนวนค่าไฟฟ้า")
units = int (input("กรุณากรอกจำนวนค่าไฟฟ้าที่ใช้ : "))
if units <= 20:
  total =  units *10
else:
  total =  units *15
print("ค่าไฟที่ต้องจ่ายคือ " , total, "บาท")
# Out:
# welcom to Coding Final 4/4
#
#  ( : satang:)
# ยินดีต้อนรับเข้าสู่โปรแกรมการคำนวนค่าไฟฟ้า
# กรุณากรอกจำนวนค่าไฟฟ้าที่ใช้ : 45
# ค่าไฟที่ต้องจ่ายคือ  675 บาท
